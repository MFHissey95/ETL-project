# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
rds_connection_string = "postgres:delphicitb969@localhost:5432/education_db"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
csv_file = "education-statistics/EdStatsCountry.csv"
edstats_country_df = pd.read_csv(csv_file)
edstats_country_df.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit  \
# 0           AW   Aruban florin
# 1           AF  Afghan afghani
# 2           AO  Angolan kwanza
# 3           AL    Albanian lek
# 4           AD            Euro
#
#                                        Special Notes  \
# 0  SNA data for 2000-2011 are updated from offici...
# 1  Fiscal year end: March 20; reporting period fo...
# 2  April 2013 database update: Based on IMF data,...
# 3                                                NaN
# 4                                                NaN
#
#                       Region          Income Group WB-2 code  \
# 0  Latin America & Caribbean  High income: nonOECD        AW
# 1                 South Asia            Low income        AF
# 2         Sub-Saharan Africa   Upper middle income        AO
# 3      Europe & Central Asia   Upper middle income        AL
# 4      Europe & Central Asia  High income: nonOECD        AD
#
#                          National accounts base year  \
# 0                                               2000
# 1                                            2002/03
# 2                                               2002
# 3  Original chained constant price data are resca...
# 4                                               1990
#
#    National accounts reference year                   SNA price valuation  \
# 0                               NaN     Value added at basic prices (VAB)
# 1                               NaN     Value added at basic prices (VAB)
# 2                               NaN  Value added at producer prices (VAP)
# 3                            1996.0     Value added at basic prices (VAB)
# 4                               NaN                                   NaN
#
#   Lending category Other groups  \
# 0              NaN          NaN
# 1              IDA         HIPC
# 2             IBRD          NaN
# 3             IBRD          NaN
# 4              NaN          NaN
#
#                          System of National Accounts  \
# 0  Country uses the 1993 System of National Accou...
# 1  Country uses the 1993 System of National Accou...
# 2  Country uses the 1993 System of National Accou...
# 3  Country uses the 1993 System of National Accou...
# 4  Country uses the 1968 System of National Accou...
#
#   Alternative conversion factor PPP survey year  \
# 0                           NaN             NaN
# 1                           NaN             NaN
# 2                       1991–96            2005
# 3                           NaN         Rolling
# 4                           NaN             NaN
#
#               Balance of Payments Manual in use
# 0  IMF Balance of Payments Manual, 6th edition.
# 1                                           NaN
# 2  IMF Balance of Payments Manual, 6th edition.
# 3  IMF Balance of Payments Manual, 6th edition.
# 4                                           NaN

# %%
edstats_country = edstats_country_df[['Country Code', 'Short Name', 'Table Name', 'Long Name', '2-alpha code', 'Currency Unit', 'Region', 'Income Group']].copy()
edstats_country.head()
# Out:
#   Country Code   Short Name   Table Name                     Long Name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   2-alpha code   Currency Unit                     Region  \
# 0           AW   Aruban florin  Latin America & Caribbean
# 1           AF  Afghan afghani                 South Asia
# 2           AO  Angolan kwanza         Sub-Saharan Africa
# 3           AL    Albanian lek      Europe & Central Asia
# 4           AD            Euro      Europe & Central Asia
#
#            Income Group
# 0  High income: nonOECD
# 1            Low income
# 2   Upper middle income
# 3   Upper middle income
# 4  High income: nonOECD

# %%
edstats_country = edstats_country.rename(columns={"Country Code": "country_code",
                                                  "Short Name": "short_name",
                                                  "Table Name": "proper_name",
                                                  "Long Name":"long_name",
                                                  "2-alpha code": "two_alpha_code",
                                                  "Currency Unit": "currency_unit",
                                                  "Region": "region",
                                                  "Income Group": "income_group",})
edstats_country.head()
# Out:
#   country_code   short_name  proper_name                     long_name  \
# 0          ABW        Aruba        Aruba                         Aruba
# 1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2          AGO       Angola       Angola   People's Republic of Angola
# 3          ALB      Albania      Albania           Republic of Albania
# 4          AND      Andorra      Andorra       Principality of Andorra
#
#   two_alpha_code   currency_unit                     region  \
# 0             AW   Aruban florin  Latin America & Caribbean
# 1             AF  Afghan afghani                 South Asia
# 2             AO  Angolan kwanza         Sub-Saharan Africa
# 3             AL    Albanian lek      Europe & Central Asia
# 4             AD            Euro      Europe & Central Asia
#
#            income_group
# 0  High income: nonOECD
# 1            Low income
# 2   Upper middle income
# 3   Upper middle income
# 4  High income: nonOECD

# %%
csv_file = "education-statistics/EdStatsCountry-Series.csv"
edstats_country_series_df = pd.read_csv(csv_file)
edstats_country_series_df.head()
# Out:
#    ID Unique CountryCode         SeriesCode  \
# 0          1         ABW        SP.POP.TOTL
# 1          2         ABW        SP.POP.GROW
# 2          3         AFG        SP.POP.GROW
# 3          4         AFG  NY.GDP.PCAP.PP.CD
# 4          5         AFG        SP.POP.TOTL
#
#                                          DESCRIPTION
# 0  Data sources : United Nations World Population...
# 1  Data sources: United Nations World Population ...
# 2  Data sources: United Nations World Population ...
# 3                 Estimates are based on regression.
# 4  Data sources : United Nations World Population...

# %%
edstats_country_series = edstats_country_series_df[['ID Unique','CountryCode','SeriesCode']].copy()
edstats_country_series.head()
# Out:
#    ID Unique CountryCode         SeriesCode
# 0          1         ABW        SP.POP.TOTL
# 1          2         ABW        SP.POP.GROW
# 2          3         AFG        SP.POP.GROW
# 3          4         AFG  NY.GDP.PCAP.PP.CD
# 4          5         AFG        SP.POP.TOTL

# %%
edstats_country_series = edstats_country_series.rename(columns={"ID Unique": "id_unique",
                                                                "CountryCode": "country_code",
                                                                "SeriesCode": "series_code"})
edstats_country_series.head()
# Out:
#    id_unique country_code        series_code
# 0          1          ABW        SP.POP.TOTL
# 1          2          ABW        SP.POP.GROW
# 2          3          AFG        SP.POP.GROW
# 3          4          AFG  NY.GDP.PCAP.PP.CD
# 4          5          AFG        SP.POP.TOTL

# %%
csv_file = "education-statistics/EdStatsSeries.csv"
edstats_series_df = pd.read_csv(csv_file)
edstats_series_df.head()
# Out:
#    id_unique          Series Code       Topic  \
# 0          1  BAR.NOED.1519.FE.ZS  Attainment
# 1          2     BAR.NOED.1519.ZS  Attainment
# 2          3  BAR.NOED.15UP.FE.ZS  Attainment
# 3          4     BAR.NOED.15UP.ZS  Attainment
# 4          5  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     Short definition  \
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...
#
#                                      Long definition  Unnamed: 6 Unnamed: 7  \
# 0  Percentage of female population age 15-19 with...         NaN        NaN
# 1  Percentage of population age 15-19 with no edu...         NaN        NaN
# 2  Percentage of female population age 15+ with n...         NaN        NaN
# 3  Percentage of population age 15+ with no educa...         NaN        NaN
# 4  Percentage of female population age 20-24 with...         NaN        NaN
#
#   Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11  Unnamed: 12 Unnamed: 13  \
# 0        NaN        NaN         NaN         NaN          NaN         NaN
# 1        NaN        NaN         NaN         NaN          NaN         NaN
# 2        NaN        NaN         NaN         NaN          NaN         NaN
# 3        NaN        NaN         NaN         NaN          NaN         NaN
# 4        NaN        NaN         NaN         NaN          NaN         NaN
#
#   Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# 0         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN

# %%
edstats_series = edstats_series_df[['id_unique','Series Code', 'Topic', 'Indicator Name', 'Short definition']].copy()
edstats_series.head()
# Out:
#    id_unique          Series Code       Topic  \
# 0          1  BAR.NOED.1519.FE.ZS  Attainment
# 1          2     BAR.NOED.1519.ZS  Attainment
# 2          3  BAR.NOED.15UP.FE.ZS  Attainment
# 3          4     BAR.NOED.15UP.ZS  Attainment
# 4          5  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       Indicator Name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     Short definition
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...

# %%
edstats_series = edstats_series.rename(columns={"Series Code": "series_code",
                                                "Topic": "topic",
                                                "Indicator Name": "indicator_name",
                                                "Short definition":"short_definition"})
edstats_series.head()
# Out:
#    id_unique          series_code       topic  \
# 0          1  BAR.NOED.1519.FE.ZS  Attainment
# 1          2     BAR.NOED.1519.ZS  Attainment
# 2          3  BAR.NOED.15UP.FE.ZS  Attainment
# 3          4     BAR.NOED.15UP.ZS  Attainment
# 4          5  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       indicator_name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     short_definition
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...

# %%
engine.table_names()
# Out:
# ['edstats_country', 'edstats_country_series', 'edstats_series']

# %%
edstats_country.to_sql(name='edstats_country', con=engine, if_exists='replace', index=True)

# %%
edstats_country_series.to_sql(name='edstats_country_series', con=engine, if_exists='replace', index=True)

# %%
edstats_series.to_sql(name='edstats_series', con=engine, if_exists='replace', index=True)

# %%
pd.read_sql_query('SELECT * from edstats_series', con=engine).head()
# Out:
#    index  id_unique          series_code       topic  \
# 0      0          1  BAR.NOED.1519.FE.ZS  Attainment
# 1      1          2     BAR.NOED.1519.ZS  Attainment
# 2      2          3  BAR.NOED.15UP.FE.ZS  Attainment
# 3      3          4     BAR.NOED.15UP.ZS  Attainment
# 4      4          5  BAR.NOED.2024.FE.ZS  Attainment
#
#                                       indicator_name  \
# 0  Barro-Lee: Percentage of female population age...
# 1  Barro-Lee: Percentage of population age 15-19 ...
# 2  Barro-Lee: Percentage of female population age...
# 3  Barro-Lee: Percentage of population age 15+ wi...
# 4  Barro-Lee: Percentage of female population age...
#
#                                     short_definition
# 0  Percentage of female population age 15-19 with...
# 1  Percentage of population age 15-19 with no edu...
# 2  Percentage of female population age 15+ with n...
# 3  Percentage of population age 15+ with no educa...
# 4  Percentage of female population age 20-24 with...

# %%
pd.read_sql_query('SELECT * from edstats_country_series', con=engine).head()
# Out:
#    index  id_unique country_code        series_code
# 0      0          1          ABW        SP.POP.TOTL
# 1      1          2          ABW        SP.POP.GROW
# 2      2          3          AFG        SP.POP.GROW
# 3      3          4          AFG  NY.GDP.PCAP.PP.CD
# 4      4          5          AFG        SP.POP.TOTL

# %%
pd.read_sql_query('SELECT * from edstats_country', con=engine).head()
# Out:
#    index country_code   short_name  proper_name                     long_name  \
# 0      0          ABW        Aruba        Aruba                         Aruba
# 1      1          AFG  Afghanistan  Afghanistan  Islamic State of Afghanistan
# 2      2          AGO       Angola       Angola   People's Republic of Angola
# 3      3          ALB      Albania      Albania           Republic of Albania
# 4      4          AND      Andorra      Andorra       Principality of Andorra
#
#   two_alpha_code   currency_unit                     region  \
# 0             AW   Aruban florin  Latin America & Caribbean
# 1             AF  Afghan afghani                 South Asia
# 2             AO  Angolan kwanza         Sub-Saharan Africa
# 3             AL    Albanian lek      Europe & Central Asia
# 4             AD            Euro      Europe & Central Asia
#
#            income_group
# 0  High income: nonOECD
# 1            Low income
# 2   Upper middle income
# 3   Upper middle income
# 4  High income: nonOECD

# %%
pd.read_sql_query('SELECT edstats_country.short_name,edstats_country.proper_name,edstats_country.long_name,edstats_country.two_alpha_code,edstats_country.currency_unit,edstats_country.region,edstats_country.income_group, edstats_country.country_code, edstats_country_series.series_code,edstats_series.topic,edstats_series.indicator_name,edstats_series.short_definition FROM edstats_country_series INNER JOIN edstats_country ON edstats_country.country_code=edstats_country_series.country_code INNER JOIN edstats_series ON edstats_country_series.series_code=edstats_series.series_code;', con=engine).head()
# Out:
#     short_name  proper_name                     long_name two_alpha_code  \
# 0        Aruba        Aruba                         Aruba             AW
# 1        Aruba        Aruba                         Aruba             AW
# 2  Afghanistan  Afghanistan  Islamic State of Afghanistan             AF
# 3  Afghanistan  Afghanistan  Islamic State of Afghanistan             AF
# 4  Afghanistan  Afghanistan  Islamic State of Afghanistan             AF
#
#     currency_unit                     region          income_group  \
# 0   Aruban florin  Latin America & Caribbean  High income: nonOECD
# 1   Aruban florin  Latin America & Caribbean  High income: nonOECD
# 2  Afghan afghani                 South Asia            Low income
# 3  Afghan afghani                 South Asia            Low income
# 4  Afghan afghani                 South Asia            Low income
#
#   country_code        series_code  \
# 0          ABW        SP.POP.TOTL
# 1          ABW        SP.POP.GROW
# 2          AFG        SP.POP.GROW
# 3          AFG  NY.GDP.PCAP.PP.CD
# 4          AFG        SP.POP.TOTL
#
#                                              topic  \
# 0                    Health: Population: Structure
# 1                     Health: Population: Dynamics
# 2                     Health: Population: Dynamics
# 3  Economic Policy & Debt: Purchasing power parity
# 4                    Health: Population: Structure
#
#                                   indicator_name  \
# 0                              Population, total
# 1                   Population growth (annual %)
# 2                   Population growth (annual %)
# 3  GDP per capita, PPP (current international $)
# 4                              Population, total
#
#                                     short_definition
# 0                                               None
# 1  Annual population growth rate. Population is b...
# 2  Annual population growth rate. Population is b...
# 3                                               None
# 4                                               None
